# %%
import json
import pandas as pd

# %%
def count_all_potential_columns(json_file_path):
    with open(json_file_path, 'r') as f:
        data = json.load(f)
    
    field_counts = {}
    openfda_field_counts = {}
    total_records = len(data.get('results', []))
    
    for record in data.get('results', []):
        for key, value in record.items():
            if key not in field_counts:
                field_counts[key] = 0
            if value and (not isinstance(value, list) or len(value) > 0):
                field_counts[key] += 1
        
        openfda = record.get('openfda', {})
        for key, value in openfda.items():
            openfda_key = f"openfda_{key}"
            if openfda_key not in openfda_field_counts:
                openfda_field_counts[openfda_key] = 0
            if value and (not isinstance(value, list) or len(value) > 0):
                openfda_field_counts[openfda_key] += 1
    
    all_field_counts = {**field_counts, **openfda_field_counts}
    
    print(f"Total records analyzed: {total_records}")
    print(f"Total potential columns without simplification: {len(all_field_counts)}")
    print(f"Top-level fields: {len(field_counts)}")
    print(f"OpenFDA fields: {len(openfda_field_counts)}")
    print(f"Current simplified structure has: {len(['id', 'brand_name', 'generic_name', 'manufacturer_name', 'product_type', 'route', 'desc', 'additional_info'])} columns")
    
    print("\nField usage frequency (sorted by usage count):")
    sorted_fields = sorted(all_field_counts.items(), key=lambda x: x[1], reverse=True)
    
    for field, count in sorted_fields:
        percentage = (count / total_records) * 100
        print(f"  {field}: {count}/{total_records} ({percentage:.1f}%)")
    
    rare_fields = [field for field, count in sorted_fields if count / total_records < 0.2]
    print(f"\nFields used in less than 20% of records ({len(rare_fields)} fields):")
    for field in rare_fields:
        count = all_field_counts[field]
        percentage = (count / total_records) * 100
        print(f"  {field}: {count}/{total_records} ({percentage:.1f}%)")
    
    return all_field_counts

potential_columns = count_all_potential_columns("../data/openfda/drug-label-0001-of-0013.json")
# Out:
# Total records analyzed: 20000
# Total potential columns without simplification: 162
# Top-level fields: 141
# OpenFDA fields: 21
# Current simplified structure has: 8 columns
#
# Field usage frequency (sorted by usage count):
#   set_id: 20000/20000 (100.0%)
#   id: 20000/20000 (100.0%)
#   effective_time: 20000/20000 (100.0%)
#   version: 20000/20000 (100.0%)
#   spl_product_data_elements: 19968/20000 (99.8%)
#   package_label_principal_display_panel: 19960/20000 (99.8%)
#   indications_and_usage: 19164/20000 (95.8%)
#   dosage_and_administration: 19133/20000 (95.7%)
#   warnings: 15991/20000 (80.0%)
#   inactive_ingredient: 12603/20000 (63.0%)
#   active_ingredient: 12413/20000 (62.1%)
#   purpose: 12339/20000 (61.7%)
#   keep_out_of_reach_of_children: 12255/20000 (61.3%)
#   spl_unclassified_section: 8317/20000 (41.6%)
#   description: 7368/20000 (36.8%)
#   stop_use: 7073/20000 (35.4%)
#   adverse_reactions: 7026/20000 (35.1%)
#   how_supplied: 7003/20000 (35.0%)
#   contraindications: 6888/20000 (34.4%)
#   clinical_pharmacology: 6809/20000 (34.0%)
#   overdosage: 6489/20000 (32.4%)
#   storage_and_handling: 6018/20000 (30.1%)
#   when_using: 5914/20000 (29.6%)
#   questions: 5786/20000 (28.9%)
#   do_not_use: 5478/20000 (27.4%)
#   openfda: 5460/20000 (27.3%)
#   openfda_brand_name: 5460/20000 (27.3%)
#   openfda_generic_name: 5460/20000 (27.3%)
#   openfda_manufacturer_name: 5460/20000 (27.3%)
#   openfda_product_ndc: 5460/20000 (27.3%)
#   openfda_product_type: 5460/20000 (27.3%)
#   openfda_spl_id: 5460/20000 (27.3%)
#   openfda_spl_set_id: 5460/20000 (27.3%)
#   openfda_package_ndc: 5460/20000 (27.3%)
#   openfda_route: 5373/20000 (26.9%)
#   openfda_unii: 5361/20000 (26.8%)
#   openfda_substance_name: 5359/20000 (26.8%)
#   pregnancy: 5312/20000 (26.6%)
#   pediatric_use: 5285/20000 (26.4%)
#   drug_interactions: 5207/20000 (26.0%)
#   information_for_patients: 5133/20000 (25.7%)
#   carcinogenesis_and_mutagenesis_and_impairment_of_fertility: 4783/20000 (23.9%)
#   openfda_application_number: 4602/20000 (23.0%)
#   geriatric_use: 4448/20000 (22.2%)
#   openfda_is_original_packager: 4146/20000 (20.7%)
#   nursing_mothers: 3977/20000 (19.9%)
#   openfda_rxcui: 3896/20000 (19.5%)
#   precautions: 3879/20000 (19.4%)
#   pharmacokinetics: 3818/20000 (19.1%)
#   clinical_studies: 3515/20000 (17.6%)
#   warnings_and_cautions: 3443/20000 (17.2%)
#   dosage_and_administration_table: 3395/20000 (17.0%)
#   ask_doctor: 3386/20000 (16.9%)
#   adverse_reactions_table: 3290/20000 (16.4%)
#   mechanism_of_action: 3167/20000 (15.8%)
#   pregnancy_or_breast_feeding: 3128/20000 (15.6%)
#   dosage_forms_and_strengths: 3121/20000 (15.6%)
#   use_in_specific_populations: 3119/20000 (15.6%)
#   nonclinical_toxicology: 2985/20000 (14.9%)
#   boxed_warning: 2553/20000 (12.8%)
#   pharmacodynamics: 2402/20000 (12.0%)
#   clinical_studies_table: 2143/20000 (10.7%)
#   clinical_pharmacology_table: 2133/20000 (10.7%)
#   general_precautions: 2121/20000 (10.6%)
#   recent_major_changes: 1764/20000 (8.8%)
#   openfda_upc: 1731/20000 (8.7%)
#   other_safety_information: 1729/20000 (8.6%)
#   ask_doctor_or_pharmacist: 1711/20000 (8.6%)
#   spl_medguide: 1676/20000 (8.4%)
#   openfda_nui: 1665/20000 (8.3%)
#   openfda_pharm_class_epc: 1577/20000 (7.9%)
#   drug_abuse_and_dependence: 1482/20000 (7.4%)
#   labor_and_delivery: 1404/20000 (7.0%)
#   openfda_original_packager_product_ndc: 1314/20000 (6.6%)
#   pharmacokinetics_table: 1313/20000 (6.6%)
#   laboratory_tests: 1279/20000 (6.4%)
#   teratogenic_effects: 1215/20000 (6.1%)
#   references: 1193/20000 (6.0%)
#   how_supplied_table: 982/20000 (4.9%)
#   openfda_pharm_class_cs: 949/20000 (4.7%)
#   spl_patient_package_insert: 940/20000 (4.7%)
#   drug_interactions_table: 876/20000 (4.4%)
#   animal_pharmacology_and_or_toxicology: 858/20000 (4.3%)
#   spl_medguide_table: 826/20000 (4.1%)
#   openfda_pharm_class_pe: 718/20000 (3.6%)
#   drug_and_or_laboratory_test_interactions: 694/20000 (3.5%)
#   openfda_pharm_class_moa: 680/20000 (3.4%)
#   warnings_and_cautions_table: 636/20000 (3.2%)
#   controlled_substance: 615/20000 (3.1%)
#   abuse: 589/20000 (2.9%)
#   dependence: 556/20000 (2.8%)
#   nonteratogenic_effects: 503/20000 (2.5%)
#   instructions_for_use: 481/20000 (2.4%)
#   spl_unclassified_section_table: 430/20000 (2.1%)
#   microbiology: 427/20000 (2.1%)
#   active_ingredient_table: 411/20000 (2.1%)
#   description_table: 348/20000 (1.7%)
#   spl_patient_package_insert_table: 344/20000 (1.7%)
#   recent_major_changes_table: 342/20000 (1.7%)
#   warnings_table: 339/20000 (1.7%)
#   purpose_table: 334/20000 (1.7%)
#   pharmacodynamics_table: 264/20000 (1.3%)
#   precautions_table: 177/20000 (0.9%)
#   use_in_specific_populations_table: 163/20000 (0.8%)
#   information_for_patients_table: 148/20000 (0.7%)
#   dosage_forms_and_strengths_table: 137/20000 (0.7%)
#   microbiology_table: 125/20000 (0.6%)
#   components: 123/20000 (0.6%)
#   indications_and_usage_table: 120/20000 (0.6%)
#   patient_medication_information: 104/20000 (0.5%)
#   pediatric_use_table: 101/20000 (0.5%)
#   package_label_principal_display_panel_table: 95/20000 (0.5%)
#   instructions_for_use_table: 84/20000 (0.4%)
#   safe_handling_warning: 73/20000 (0.4%)
#   route: 64/20000 (0.3%)
#   risks: 60/20000 (0.3%)
#   geriatric_use_table: 40/20000 (0.2%)
#   pharmacogenomics: 32/20000 (0.2%)
#   general_precautions_table: 28/20000 (0.1%)
#   intended_use_of_the_device: 27/20000 (0.1%)
#   storage_and_handling_table: 24/20000 (0.1%)
#   patient_medication_information_table: 24/20000 (0.1%)
#   nonclinical_toxicology_table: 23/20000 (0.1%)
#   user_safety_warnings: 19/20000 (0.1%)
#   cleaning: 18/20000 (0.1%)
#   information_for_owners_or_caregivers: 18/20000 (0.1%)
#   carcinogenesis_and_mutagenesis_and_impairment_of_fertility_table: 17/20000 (0.1%)
#   health_care_provider_letter: 14/20000 (0.1%)
#   contraindications_table: 13/20000 (0.1%)
#   inactive_ingredient_table: 12/20000 (0.1%)
#   overdosage_table: 11/20000 (0.1%)
#   pregnancy_table: 10/20000 (0.1%)
#   references_table: 10/20000 (0.1%)
#   spl_indexing_data_elements: 9/20000 (0.0%)
#   statement_of_identity: 8/20000 (0.0%)
#   drug_and_or_laboratory_test_interactions_table: 8/20000 (0.0%)
#   questions_table: 8/20000 (0.0%)
#   keep_out_of_reach_of_children_table: 8/20000 (0.0%)
#   health_care_provider_letter_table: 6/20000 (0.0%)
#   stop_use_table: 6/20000 (0.0%)
#   do_not_use_table: 5/20000 (0.0%)
#   boxed_warning_table: 5/20000 (0.0%)
#   disposal_and_waste_handling: 5/20000 (0.0%)
#   mechanism_of_action_table: 5/20000 (0.0%)
#   laboratory_tests_table: 5/20000 (0.0%)
#   drug_abuse_and_dependence_table: 4/20000 (0.0%)
#   accessories: 4/20000 (0.0%)
#   abuse_table: 3/20000 (0.0%)
#   when_using_table: 3/20000 (0.0%)
#   ask_doctor_table: 3/20000 (0.0%)
#   pregnancy_or_breast_feeding_table: 3/20000 (0.0%)
#   ask_doctor_or_pharmacist_table: 3/20000 (0.0%)
#   health_claim: 2/20000 (0.0%)
#   troubleshooting: 2/20000 (0.0%)
#   information_for_owners_or_caregivers_table: 2/20000 (0.0%)
#   animal_pharmacology_and_or_toxicology_table: 1/20000 (0.0%)
#   summary_of_safety_and_effectiveness: 1/20000 (0.0%)
#   risks_table: 1/20000 (0.0%)
#   veterinary_indications: 1/20000 (0.0%)
#   alarms: 1/20000 (0.0%)
#   calibration_instructions: 1/20000 (0.0%)
#   other_safety_information_table: 1/20000 (0.0%)
#
# Fields used in less than 20% of records (117 fields):
#   nursing_mothers: 3977/20000 (19.9%)
#   openfda_rxcui: 3896/20000 (19.5%)
#   precautions: 3879/20000 (19.4%)
#   pharmacokinetics: 3818/20000 (19.1%)
#   clinical_studies: 3515/20000 (17.6%)
#   warnings_and_cautions: 3443/20000 (17.2%)
#   dosage_and_administration_table: 3395/20000 (17.0%)
#   ask_doctor: 3386/20000 (16.9%)
#   adverse_reactions_table: 3290/20000 (16.4%)
#   mechanism_of_action: 3167/20000 (15.8%)
#   pregnancy_or_breast_feeding: 3128/20000 (15.6%)
#   dosage_forms_and_strengths: 3121/20000 (15.6%)
#   use_in_specific_populations: 3119/20000 (15.6%)
#   nonclinical_toxicology: 2985/20000 (14.9%)
#   boxed_warning: 2553/20000 (12.8%)
#   pharmacodynamics: 2402/20000 (12.0%)
#   clinical_studies_table: 2143/20000 (10.7%)
#   clinical_pharmacology_table: 2133/20000 (10.7%)
#   general_precautions: 2121/20000 (10.6%)
#   recent_major_changes: 1764/20000 (8.8%)
#   openfda_upc: 1731/20000 (8.7%)
#   other_safety_information: 1729/20000 (8.6%)
#   ask_doctor_or_pharmacist: 1711/20000 (8.6%)
#   spl_medguide: 1676/20000 (8.4%)
#   openfda_nui: 1665/20000 (8.3%)
#   openfda_pharm_class_epc: 1577/20000 (7.9%)
#   drug_abuse_and_dependence: 1482/20000 (7.4%)
#   labor_and_delivery: 1404/20000 (7.0%)
#   openfda_original_packager_product_ndc: 1314/20000 (6.6%)
#   pharmacokinetics_table: 1313/20000 (6.6%)
#   laboratory_tests: 1279/20000 (6.4%)
#   teratogenic_effects: 1215/20000 (6.1%)
#   references: 1193/20000 (6.0%)
#   how_supplied_table: 982/20000 (4.9%)
#   openfda_pharm_class_cs: 949/20000 (4.7%)
#   spl_patient_package_insert: 940/20000 (4.7%)
#   drug_interactions_table: 876/20000 (4.4%)
#   animal_pharmacology_and_or_toxicology: 858/20000 (4.3%)
#   spl_medguide_table: 826/20000 (4.1%)
#   openfda_pharm_class_pe: 718/20000 (3.6%)
#   drug_and_or_laboratory_test_interactions: 694/20000 (3.5%)
#   openfda_pharm_class_moa: 680/20000 (3.4%)
#   warnings_and_cautions_table: 636/20000 (3.2%)
#   controlled_substance: 615/20000 (3.1%)
#   abuse: 589/20000 (2.9%)
#   dependence: 556/20000 (2.8%)
#   nonteratogenic_effects: 503/20000 (2.5%)
#   instructions_for_use: 481/20000 (2.4%)
#   spl_unclassified_section_table: 430/20000 (2.1%)
#   microbiology: 427/20000 (2.1%)
#   active_ingredient_table: 411/20000 (2.1%)
#   description_table: 348/20000 (1.7%)
#   spl_patient_package_insert_table: 344/20000 (1.7%)
#   recent_major_changes_table: 342/20000 (1.7%)
#   warnings_table: 339/20000 (1.7%)
#   purpose_table: 334/20000 (1.7%)
#   pharmacodynamics_table: 264/20000 (1.3%)
#   precautions_table: 177/20000 (0.9%)
#   use_in_specific_populations_table: 163/20000 (0.8%)
#   information_for_patients_table: 148/20000 (0.7%)
#   dosage_forms_and_strengths_table: 137/20000 (0.7%)
#   microbiology_table: 125/20000 (0.6%)
#   components: 123/20000 (0.6%)
#   indications_and_usage_table: 120/20000 (0.6%)
#   patient_medication_information: 104/20000 (0.5%)
#   pediatric_use_table: 101/20000 (0.5%)
#   package_label_principal_display_panel_table: 95/20000 (0.5%)
#   instructions_for_use_table: 84/20000 (0.4%)
#   safe_handling_warning: 73/20000 (0.4%)
#   route: 64/20000 (0.3%)
#   risks: 60/20000 (0.3%)
#   geriatric_use_table: 40/20000 (0.2%)
#   pharmacogenomics: 32/20000 (0.2%)
#   general_precautions_table: 28/20000 (0.1%)
#   intended_use_of_the_device: 27/20000 (0.1%)
#   storage_and_handling_table: 24/20000 (0.1%)
#   patient_medication_information_table: 24/20000 (0.1%)
#   nonclinical_toxicology_table: 23/20000 (0.1%)
#   user_safety_warnings: 19/20000 (0.1%)
#   cleaning: 18/20000 (0.1%)
#   information_for_owners_or_caregivers: 18/20000 (0.1%)
#   carcinogenesis_and_mutagenesis_and_impairment_of_fertility_table: 17/20000 (0.1%)
#   health_care_provider_letter: 14/20000 (0.1%)
#   contraindications_table: 13/20000 (0.1%)
#   inactive_ingredient_table: 12/20000 (0.1%)
#   overdosage_table: 11/20000 (0.1%)
#   pregnancy_table: 10/20000 (0.1%)
#   references_table: 10/20000 (0.1%)
#   spl_indexing_data_elements: 9/20000 (0.0%)
#   statement_of_identity: 8/20000 (0.0%)
#   drug_and_or_laboratory_test_interactions_table: 8/20000 (0.0%)
#   questions_table: 8/20000 (0.0%)
#   keep_out_of_reach_of_children_table: 8/20000 (0.0%)
#   health_care_provider_letter_table: 6/20000 (0.0%)
#   stop_use_table: 6/20000 (0.0%)
#   do_not_use_table: 5/20000 (0.0%)
#   boxed_warning_table: 5/20000 (0.0%)
#   disposal_and_waste_handling: 5/20000 (0.0%)
#   mechanism_of_action_table: 5/20000 (0.0%)
#   laboratory_tests_table: 5/20000 (0.0%)
#   drug_abuse_and_dependence_table: 4/20000 (0.0%)
#   accessories: 4/20000 (0.0%)
#   abuse_table: 3/20000 (0.0%)
#   when_using_table: 3/20000 (0.0%)
#   ask_doctor_table: 3/20000 (0.0%)
#   pregnancy_or_breast_feeding_table: 3/20000 (0.0%)
#   ask_doctor_or_pharmacist_table: 3/20000 (0.0%)
#   health_claim: 2/20000 (0.0%)
#   troubleshooting: 2/20000 (0.0%)
#   information_for_owners_or_caregivers_table: 2/20000 (0.0%)
#   animal_pharmacology_and_or_toxicology_table: 1/20000 (0.0%)
#   summary_of_safety_and_effectiveness: 1/20000 (0.0%)
#   risks_table: 1/20000 (0.0%)
#   veterinary_indications: 1/20000 (0.0%)
#   alarms: 1/20000 (0.0%)
#   calibration_instructions: 1/20000 (0.0%)
#   other_safety_information_table: 1/20000 (0.0%)
